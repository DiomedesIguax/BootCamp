# %% [markdown]
# <a href="https://colab.research.google.com/github/DiomedesIguax/BootCamp/blob/main/Prediccion_inf_Tasas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Paso 1 - ENTENDER EL PROBLEMA

# %% [markdown]
# ![Captura de pantalla 2026-06-13 073507.png](data:image/png;base64,...)

# %% [markdown]
# # Paso 2 - LIBRERIAS
